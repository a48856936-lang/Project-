# %% [markdown]
# <a href="https://colab.research.google.com/github/a48856936-lang/Project-/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create E-Commerce Sales Database

data = {
    "Order_ID":[1001,1002,1003,1004,1005,1006,1007,1008,1009,1010],

    "Date":[
        "2026-01-05",
        "2026-01-10",
        "2026-02-15",
        "2026-02-20",
        "2026-03-02",
        "2026-03-12",
        "2026-04-08",
        "2026-04-18",
        "2026-05-10",
        "2026-05-20"
    ],

    "Customer_Name":[
        "Arun","Ravi","Kumar","Priya","Anu",
        "Vijay","Kavi","Mani","Siva","Devi"
    ],

    "Category":[
        "Electronics","Electronics","Clothing","Home",
        "Electronics","Beauty","Clothing","Home",
        "Electronics","Beauty"
    ],

    "Product":[
        "Laptop","Mobile","Shirt","Chair","Headphones",
        "Perfume","Shoes","Table","Laptop","Cream"
    ],

    "Quantity":[2,3,5,4,6,3,2,1,1,4],

    "Price":[50000,20000,1500,3000,2000,2500,4000,7000,50000,1000],

    "Sales":[100000,60000,7500,12000,12000,7500,8000,7000,50000,4000]
}


df = pd.DataFrame(data)

# Show Database

df
# Out:
#    Order_ID        Date Customer_Name     Category     Product  Quantity  \
# 0      1001  2026-01-05          Arun  Electronics      Laptop         2
# 1      1002  2026-01-10          Ravi  Electronics      Mobile         3
# 2      1003  2026-02-15         Kumar     Clothing       Shirt         5
# 3      1004  2026-02-20         Priya         Home       Chair         4
# 4      1005  2026-03-02           Anu  Electronics  Headphones         6
# 5      1006  2026-03-12         Vijay       Beauty     Perfume         3
# 6      1007  2026-04-08          Kavi     Clothing       Shoes         2
# 7      1008  2026-04-18          Mani         Home       Table         1
# 8      1009  2026-05-10          Siva  Electronics      Laptop         1
# 9      1010  2026-05-20          Devi       Beauty       Cream         4
#
#    Price   Sales
# 0  50000  100000
# 1  20000   60000
# 2   1500    7500
# 3   3000   12000
# 4   2000   12000
# 5   2500    7500
# 6   4000    8000
# ...
